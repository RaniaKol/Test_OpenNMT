# %%
import torch

# %%
# !nproc --all
# Out:
# 16

# %%
# !onmt_build_vocab -config config.yaml -n_sample -1 -num_threads 16
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2023-05-21 01:01:59,225 INFO] Counter vocab from -1 samples.
# [2023-05-21 01:01:59,225 INFO] n_sample=-1: Build vocab on full datasets.
# [2023-05-21 01:02:04,760 INFO] Counters src: 29049
# [2023-05-21 01:02:04,760 INFO] Counters tgt: 16449

# %%
# !nvidia-smi -L
# Out:
# GPU 0: NVIDIA GeForce RTX 3050 Ti Laptop GPU (UUID: GPU-a8d972fd-89a6-0e96-90b0-13cd3cf9e61a)

# %%
# !onmt_train -config config.yaml
# Out:
# [2023-05-21 01:06:27,741 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2023-05-21 01:06:27,743 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2023-05-21 01:06:27,743 INFO] Missing transforms field for valid data, set to default: [].
# [2023-05-21 01:06:27,744 INFO] Parsed 2 corpora from -data.
# [2023-05-21 01:06:27,747 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2023-05-21 01:06:28,021 INFO] Building model...
# [2023-05-21 01:06:29,949 INFO] NMTModel(
#   (encoder): TransformerEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(29056, 512, padding_idx=1)
#         )
#         (pe): PositionalEncoding()
#       )
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): ModuleList(
#       (0-5): 6 x TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
# ...

# %%
# !onmt_translate -model OpenNMT_code/model_step_1000.pt -src test_data_grc.txt -output U.txt -gpu 0 -verbose
# Out:
# [2023-05-21 15:05:03,375 INFO]
# SENT 1: ['<unk>']
# PRED 1: Nevertheless; we have always been brought to this by any decay in any decay in our heads turned by aggrandizement; no, our resources no, our resources are what they have always been, and our error has been an error of which all are equally liable.
# PRED SCORE: -0.3956
#
# [2023-05-21 15:05:03,375 INFO]
# SENT 2: ['<unk>', '<unk>', 'μὲν', 'ἦν', 'ὁ', '<unk>', '<unk>', 'ὃν', 'τῆς', '<unk>', 'γενόμενον', 'στάσεως', '<unk>', 'ἀπέκτεινε,', 'πατὴρ', 'δὲ', 'ὁ', '<unk>', '<unk>', '<unk>', 'οὐχ', 'οὕτω', 'μὲν', '<unk>', 'ἐν', 'τοῖς', '<unk>', 'ἀνὴρ', 'οὐδὲ', '<unk>', '<unk>', 'δὲ', 'καὶ', '<unk>', 'ἄλλως', 'τε', 'καὶ', 'πρὸς', 'τὰς', '<unk>', '<unk>', 'ὡς', '<unk>', 'ἑνὸς', 'ἄν', 'τις', 'ἔργου', '<unk>']
# ...
